# %% [markdown]
# # Criação do modelo de classificação para o chatbot

# %% [markdown]
# ## Importando os módulos necessários:

# %%
# !pip install tensorflow
# !pip install --upgrade tensorflow_text
# !pip install --upgrade tensorflow_hub
# !pip install pandas
# !pip install tflearn
# !pip install sklearn
# !pip install numpy

import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
import pandas as pd
from tensorflow import keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /home/luana/.local/lib/python3.10/site-packages (2.11.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: flatbuffers>=2.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (23.1.21)
# Requirement already satisfied: libclang>=13.0.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/lib/python3/dist-packages (from tensorflow) (3.12.4)
# Requirement already satisfied: wrapt>=1.11.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: packaging in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (23.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: numpy>=1.20 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow) (1.24.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/luana/.local/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/luana/.local/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/luana/.local/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/luana/.local/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.25.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/luana/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/luana/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/luana/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/luana/.local/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/luana/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/luana/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow_text in /home/luana/.local/lib/python3.10/site-packages (2.11.0)
# Collecting tensorflow_text
#   Downloading tensorflow_text-2.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 11.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow_text) (0.12.0)
# Collecting tensorflow<2.13,>=2.12.0
#   Downloading tensorflow-2.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (585.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 MB 2.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (59.6.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (3.8.0)
# Collecting keras<2.13,>=2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 21.7 MB/s eta 0:00:0000:01
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.22.3-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (1.51.3)
# Requirement already satisfied: absl-py>=1.0.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (1.4.0)
# Collecting numpy<1.24,>=1.22
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 14.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: flatbuffers>=2.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (23.1.21)
# Collecting jax>=0.3.15
#   Downloading jax-0.4.8.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.7 MB/s eta 0:00:00:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (0.31.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (4.5.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (0.4.0)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 KB 6.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: packaging in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (23.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (2.2.0)
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.2-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 25.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: libclang>=13.0.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (15.0.6.1)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (1.16.0)
# Collecting wrapt<1.15,>=1.11.0
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 1.5 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: google-pasta>=0.1.1 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow<2.13,>=2.12.0->tensorflow_text) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow<2.13,>=2.12.0->tensorflow_text) (0.37.1)
# Collecting scipy>=1.7
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 23.9 MB/s eta 0:00:0000:0100:01
# Collecting ml-dtypes>=0.0.3
#   Downloading ml_dtypes-0.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3/dist-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (2.25.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/luana/.local/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (2.2.3)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 35.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/luana/.local/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (2.16.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/luana/.local/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (3.4.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/luana/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/luana/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/luana/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/luana/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/luana/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/luana/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow<2.13,>=2.12.0->tensorflow_text) (3.2.0)
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.8-py3-none-any.whl size=1439693 sha256=d23e27bb87d86fc1417284c5b7f714fee6909f7594a3feb4ca648f50b23b997a
#   Stored in directory: /home/luana/.cache/pip/wheels/09/6f/35/a8fac8b61de8e0d9eb07988481528898561923e260b1fa7d2f
# Successfully built jax
# Installing collected packages: wrapt, tensorflow-estimator, tensorboard-data-server, protobuf, numpy, keras, scipy, ml-dtypes, jax, google-auth-oauthlib, tensorboard, tensorflow, tensorflow_text
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.15.0
#     Uninstalling wrapt-1.15.0:
#       Successfully uninstalled wrapt-1.15.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.2
#     Uninstalling numpy-1.24.2:
#       Successfully uninstalled numpy-1.24.2
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
#   Attempting uninstall: tensorflow_text
#     Found existing installation: tensorflow-text 2.11.0
#     Uninstalling tensorflow-text-2.11.0:
#       Successfully uninstalled tensorflow-text-2.11.0
# Successfully installed google-auth-oauthlib-1.0.0 jax-0.4.8 keras-2.12.0 ml-dtypes-0.1.0 numpy-1.23.5 protobuf-4.22.3 scipy-1.10.1 tensorboard-2.12.2 tensorboard-data-server-0.7.0 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow_text-2.12.1 wrapt-1.14.1
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow_hub in /home/luana/.local/lib/python3.10/site-packages (0.12.0)
# Collecting tensorflow_hub
#   Downloading tensorflow_hub-0.13.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 KB 226.2 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.12.0 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow_hub) (1.23.5)
# Requirement already satisfied: protobuf>=3.19.6 in /home/luana/.local/lib/python3.10/site-packages (from tensorflow_hub) (4.22.3)
# Installing collected packages: tensorflow_hub
#   Attempting uninstall: tensorflow_hub
#     Found existing installation: tensorflow-hub 0.12.0
#     Uninstalling tensorflow-hub-0.12.0:
#       Successfully uninstalled tensorflow-hub-0.12.0
# Successfully installed tensorflow_hub-0.13.0
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/luana/.local/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/luana/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /home/luana/.local/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tflearn in /home/luana/.local/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: numpy in /home/luana/.local/lib/python3.10/site-packages (from tflearn) (1.23.5)
# Requirement already satisfied: Pillow in /usr/lib/python3/dist-packages (from tflearn) (9.0.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from tflearn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in /home/luana/.local/lib/python3.10/site-packages (0.0.post1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/luana/.local/lib/python3.10/site-packages (1.23.5)
# 2023-05-02 16:01:59.768501: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-02 16:01:59.799206: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-02 16:01:59.800019: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-02 16:02:02.065730: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Usando uma build pré-treinada e iniciando modelo

# %% [markdown]
# + Usamos um modelo pré-treinado do Tensorflow Hub
# + Usamos o pré-processador equivalente ao modelo escolhido
# + Durante a execução, alguns warnings são exibidos. Isto se dá pela falta de uma GPU na máquina, então o aviso pode ser ignorado.

# %%
encoder_url = "https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4"
preprocess_url = "https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3"
bert_preprocess_model = hub.KerasLayer(preprocess_url)
bert_model = hub.KerasLayer(encoder_url)
# Out:
# 2023-05-02 16:02:05.387302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.387707: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.387828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.388183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.388351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.388430: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.388504: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.445972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.446426: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.446532: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.446943: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.447079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.447156: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.447234: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.512950: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.513300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.513403: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.513707: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.513855: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.513941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.514053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.654008: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.654518: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.654623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.655043: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.655196: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.655279: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:05.655357: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'seq_length' with dtype int32
# 	 [[{{node seq_length}}]]
# 2023-05-02 16:02:10.657647: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 93763584 exceeds 10% of free system memory.

# %% [markdown]
# ## Importando os dados para treinamento
#
# + Os dados devem estar armazenados no mesmo diretório que o código
# + Serão armazenados na forma de Dataframe, usando Pandas
# + Após importação, é feita a transformação da variável categórica "Tag"

# %%
df = pd.read_csv("data.csv")

df['funny'] = df['Tag'].apply(lambda x: 1 if x=='funny' else 0)
df['goodbye'] = df['Tag'].apply(lambda x: 1 if x=='goodbye' else 0)
df['greeting'] = df['Tag'].apply(lambda x: 1 if x=='greeting' else 0)
df['me'] = df['Tag'].apply(lambda x: 1 if x=='me' else 0)
df['query'] = df['Tag'].apply(lambda x: 1 if x=='query' else 0)
df['thanks'] = df['Tag'].apply(lambda x: 1 if x=='thanks' else 0)
df['use'] = df['Tag'].apply(lambda x: 1 if x=='use' else 0)

df.head(1)
# Out:
#                             Qual     Tag  funny  goodbye  greeting  me  query  \
# 0  Você pode me contar uma piada?  funny      1        0         0   0      0
#
#    thanks  use
# 0       0    0

# %% [markdown]
# ## Criação de dados de treinamento
#
# Nesta etapa, os dados salvos no dataframe são separados em duas partes:
#
# + Uma lista de frases, seriam os dados de entrada
# + Uma lista contendo a categoria (transformada em uma lista) equivalente a cada frase.
#
# Cada categoria é representada por uma lista de zeros contendo apenas um número um.

# %%
list = df.values.tolist()
intents = []
sents = []
for i in range(len(list)):
    line = list[i][2:]
    intents.append(line)
    sents.append(list[i][0])

# %% [markdown]
# ## Criando o modelo
#
# + A camada de input receberá um texto e passará adiante este texto pré-processado pelo modelo retirado do Tensorflow Hub
# + Este texto pré-processado é processado pelas camadas do bert, modelo extraído do Tensorflow Hub
# + Para evitar overfitting, foi adicionada uma camada de dropout
# + Após o dropout, foi feita uma camada de classificação. Ela possui 7 neurônios, pois o sistema possui 7 classificações distintas. A função de ativação escolhida foi a softmax pois esta se sai melhor para tarefas de classificação com múltiplas categorias.
# + O modelo é então criado com a arquitetura definida.

# %%
# Bert layers
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
preprocessed_text = bert_preprocess_model(text_input)
outputs = bert_model(preprocessed_text)

# Neural network layers
l = tf.keras.layers.Dropout(0.1, name="dropout")(outputs['pooled_output'])
l = tf.keras.layers.Dense(7, activation='softmax', name="output")(l)

# Use inputs and outputs to construct a final model
model = tf.keras.Model(inputs=[text_input], outputs = [l])
# Out:
# 2023-05-02 16:02:11.793406: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype string and shape [?]
# 	 [[{{node inputs}}]]
# 2023-05-02 16:02:11.809963: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder' with dtype string and shape [?]
# 	 [[{{node Placeholder}}]]
# 2023-05-02 16:02:11.913477: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [?,128]
# 	 [[{{node inputs}}]]
# 2023-05-02 16:02:11.913562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_2' with dtype int32 and shape [?,128]
# 	 [[{{node inputs_2}}]]
# 2023-05-02 16:02:11.980681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder_1' with dtype int32 and shape [?,128]
# 	 [[{{node Placeholder_1}}]]
# 2023-05-02 16:02:11.980777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder_2' with dtype int32 and shape [?,128]
# 	 [[{{node Placeholder_2}}]]

# %% [markdown]
# ## Definidas as métricas do modelo e feita a sua compilação

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall')
]

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=METRICS)

# %% [markdown]
# ## O modelo é então treinado
#
# + Usa-se como conjunto de treinamento as frases retiradas do dataset
# + Como trata-se de uma operação de aprendizagem supervisionada, as etiquetas para cada entrada são dadas pela categoria transformada anteriormente.
# + usamos 1000 épocas e um tamanho de batch de 10.

# %%
hist = model.fit(sents,intents,epochs=1000, batch_size=10)
# Out:
# Epoch 1/1000
# 2023-05-02 16:02:14.853055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_3' with dtype float and shape [?,?,768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_3}}]]
# 2023-05-02 16:02:14.853128: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_4' with dtype float and shape [?,?,768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_4}}]]
# 2023-05-02 16:02:14.853192: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_5' with dtype float and shape [?,?,768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_5}}]]
# 2023-05-02 16:02:14.853239: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_6' with dtype float and shape [?,?,768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_6}}]]
# 2023-05-02 16:02:14.853283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_7' with dtype float and shape [?,?,768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_7}}]]
# 2023-05-02 16:02:14.853326: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_8' with dtype float and shape [768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_8}}]]
# 2023-05-02 16:02:14.853398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_9' with dtype float and shape [?,?,768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_9}}]]
# 2023-05-02 16:02:14.853441: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_10' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_10}}]]
# 2023-05-02 16:02:14.853483: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_11' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_11}}]]
# 2023-05-02 16:02:14.853527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_12' with dtype float and shape [768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_12}}]]
# 2023-05-02 16:02:14.853570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_13' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_13}}]]
# 2023-05-02 16:02:14.853644: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_14' with dtype float
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_14}}]]
# 2023-05-02 16:02:14.853688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_15' with dtype float and shape [?,?,768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_15}}]]
# 2023-05-02 16:02:14.853729: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_16' with dtype float and shape [?,?,1]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_16}}]]
# 2023-05-02 16:02:14.853772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_17' with dtype float and shape [?,?,768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_17}}]]
# 2023-05-02 16:02:14.853813: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_18' with dtype float and shape [?,?,768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_18}}]]
# 2023-05-02 16:02:14.853854: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_19' with dtype float and shape [?,?,768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_19}}]]
# 2023-05-02 16:02:14.853895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_20' with dtype float and shape [768]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_20}}]]
# 2023-05-02 16:02:14.853938: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_23' with dtype float and shape [?,?,3072]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_23}}]]
# 2023-05-02 16:02:14.854011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall_24' with dtype float and shape [?,?,3072]
# 	 [[{{node gradients/bert_encoder/StatefulPartitionedCall_grad/bert_encoder/StatefulPartitionedCall
1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1205 - accuracy: 0.9752 - precision: 0.9439 - recall: 0.8783
# Epoch 898/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1289 - accuracy: 0.9689 - precision: 0.9327 - recall: 0.8435
# Epoch 899/1000
# 12/12 [==============================] - 8s 694ms/step - loss: 0.1265 - accuracy: 0.9727 - precision: 0.9346 - recall: 0.8696
# Epoch 900/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1218 - accuracy: 0.9702 - precision: 0.9252 - recall: 0.8609
# Epoch 901/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1353 - accuracy: 0.9702 - precision: 0.9333 - recall: 0.8522
# Epoch 902/1000
# 12/12 [==============================] - 8s 685ms/step - loss: 0.1351 - accuracy: 0.9702 - precision: 0.9252 - recall: 0.8609
# Epoch 903/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1253 - accuracy: 0.9727 - precision: 0.9266 - recall: 0.8783
# Epoch 904/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1215 - accuracy: 0.9702 - precision: 0.9099 - recall: 0.8783
# Epoch 905/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1282 - accuracy: 0.9764 - precision: 0.9444 - recall: 0.8870
# Epoch 906/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1254 - accuracy: 0.9764 - precision: 0.9528 - recall: 0.8783
# Epoch 907/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1236 - accuracy: 0.9665 - precision: 0.9151 - recall: 0.8435
# Epoch 908/1000
# 12/12 [==============================] - 8s 694ms/step - loss: 0.1176 - accuracy: 0.9739 - precision: 0.9273 - recall: 0.8870
# Epoch 909/1000
# 12/12 [==============================] - 8s 687ms/step - loss: 0.1211 - accuracy: 0.9776 - precision: 0.9533 - recall: 0.8870
# Epoch 910/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1238 - accuracy: 0.9689 - precision: 0.9167 - recall: 0.8609
# Epoch 911/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1334 - accuracy: 0.9677 - precision: 0.9238 - recall: 0.8435
# Epoch 912/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1297 - accuracy: 0.9689 - precision: 0.9245 - recall: 0.8522
# Epoch 913/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1232 - accuracy: 0.9752 - precision: 0.9439 - recall: 0.8783
# Epoch 914/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1314 - accuracy: 0.9640 - precision: 0.9057 - recall: 0.8348
# Epoch 915/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1246 - accuracy: 0.9714 - precision: 0.9340 - recall: 0.8609
# Epoch 916/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1280 - accuracy: 0.9739 - precision: 0.9434 - recall: 0.8696
# Epoch 917/1000
# 12/12 [==============================] - 8s 693ms/step - loss: 0.1191 - accuracy: 0.9702 - precision: 0.9252 - recall: 0.8609
# Epoch 918/1000
# 12/12 [==============================] - 8s 687ms/step - loss: 0.1241 - accuracy: 0.9689 - precision: 0.9327 - recall: 0.8435
# Epoch 919/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1287 - accuracy: 0.9727 - precision: 0.9346 - recall: 0.8696
# Epoch 920/1000
# 12/12 [==============================] - 8s 695ms/step - loss: 0.1269 - accuracy: 0.9689 - precision: 0.9327 - recall: 0.8435
# Epoch 921/1000
# 12/12 [==============================] - 8s 686ms/step - loss: 0.1166 - accuracy: 0.9776 - precision: 0.9619 - recall: 0.8783
# Epoch 922/1000
# 12/12 [==============================] - 8s 686ms/step - loss: 0.1243 - accuracy: 0.9677 - precision: 0.9406 - recall: 0.8261
# Epoch 923/1000
# 12/12 [==============================] - 8s 687ms/step - loss: 0.1209 - accuracy: 0.9677 - precision: 0.9238 - recall: 0.8435
# Epoch 924/1000
# 12/12 [==============================] - 8s 693ms/step - loss: 0.1233 - accuracy: 0.9714 - precision: 0.9340 - recall: 0.8609
# Epoch 925/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1183 - accuracy: 0.9714 - precision: 0.9423 - recall: 0.8522
# Epoch 926/1000
# 12/12 [==============================] - 8s 695ms/step - loss: 0.1177 - accuracy: 0.9801 - precision: 0.9626 - recall: 0.8957
# Epoch 927/1000
# 12/12 [==============================] - 8s 686ms/step - loss: 0.1229 - accuracy: 0.9727 - precision: 0.9266 - recall: 0.8783
# Epoch 928/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1209 - accuracy: 0.9665 - precision: 0.9151 - recall: 0.8435
# Epoch 929/1000
# 12/12 [==============================] - 8s 690ms/step - loss: 0.1291 - accuracy: 0.9702 - precision: 0.9417 - recall: 0.8435
# Epoch 930/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1149 - accuracy: 0.9826 - precision: 0.9720 - recall: 0.9043
# Epoch 931/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1133 - accuracy: 0.9776 - precision: 0.9369 - recall: 0.9043
# Epoch 932/1000
# 12/12 [==============================] - 8s 690ms/step - loss: 0.1257 - accuracy: 0.9677 - precision: 0.9083 - recall: 0.8609
# Epoch 933/1000
# 12/12 [==============================] - 8s 699ms/step - loss: 0.1181 - accuracy: 0.9739 - precision: 0.9519 - recall: 0.8609
# Epoch 934/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1208 - accuracy: 0.9714 - precision: 0.9423 - recall: 0.8522
# Epoch 935/1000
# 12/12 [==============================] - 8s 685ms/step - loss: 0.1262 - accuracy: 0.9776 - precision: 0.9369 - recall: 0.9043
# Epoch 936/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1200 - accuracy: 0.9839 - precision: 0.9722 - recall: 0.9130
# Epoch 937/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1244 - accuracy: 0.9640 - precision: 0.9135 - recall: 0.8261
# Epoch 938/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1218 - accuracy: 0.9652 - precision: 0.9143 - recall: 0.8348
# Epoch 939/1000
# 12/12 [==============================] - 8s 693ms/step - loss: 0.1260 - accuracy: 0.9689 - precision: 0.9327 - recall: 0.8435
# Epoch 940/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1099 - accuracy: 0.9839 - precision: 0.9636 - recall: 0.9217
# Epoch 941/1000
# 12/12 [==============================] - 8s 695ms/step - loss: 0.1231 - accuracy: 0.9801 - precision: 0.9626 - recall: 0.8957
# Epoch 942/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1258 - accuracy: 0.9640 - precision: 0.8981 - recall: 0.8435
# Epoch 943/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1125 - accuracy: 0.9714 - precision: 0.9182 - recall: 0.8783
# Epoch 944/1000
# 12/12 [==============================] - 8s 694ms/step - loss: 0.1110 - accuracy: 0.9814 - precision: 0.9545 - recall: 0.9130
# Epoch 945/1000
# 12/12 [==============================] - 8s 687ms/step - loss: 0.1125 - accuracy: 0.9764 - precision: 0.9364 - recall: 0.8957
# Epoch 946/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1169 - accuracy: 0.9764 - precision: 0.9615 - recall: 0.8696
# Epoch 947/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1168 - accuracy: 0.9789 - precision: 0.9804 - recall: 0.8696
# Epoch 948/1000
# 12/12 [==============================] - 8s 690ms/step - loss: 0.1184 - accuracy: 0.9839 - precision: 0.9636 - recall: 0.9217
# Epoch 949/1000
# 12/12 [==============================] - 8s 690ms/step - loss: 0.1246 - accuracy: 0.9677 - precision: 0.9159 - recall: 0.8522
# Epoch 950/1000
# 12/12 [==============================] - 8s 694ms/step - loss: 0.1219 - accuracy: 0.9702 - precision: 0.9417 - recall: 0.8435
# Epoch 951/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1230 - accuracy: 0.9652 - precision: 0.9223 - recall: 0.8261
# Epoch 952/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1258 - accuracy: 0.9615 - precision: 0.8962 - recall: 0.8261
# Epoch 953/1000
# 12/12 [==============================] - 8s 693ms/step - loss: 0.1184 - accuracy: 0.9727 - precision: 0.9346 - recall: 0.8696
# Epoch 954/1000
# 12/12 [==============================] - 8s 694ms/step - loss: 0.1194 - accuracy: 0.9764 - precision: 0.9528 - recall: 0.8783
# Epoch 955/1000
# 12/12 [==============================] - 8s 693ms/step - loss: 0.1126 - accuracy: 0.9776 - precision: 0.9533 - recall: 0.8870
# Epoch 956/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1188 - accuracy: 0.9789 - precision: 0.9455 - recall: 0.9043
# Epoch 957/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1292 - accuracy: 0.9590 - precision: 0.8942 - recall: 0.8087
# Epoch 958/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1327 - accuracy: 0.9578 - precision: 0.8857 - recall: 0.8087
# Epoch 959/1000
# 12/12 [==============================] - 8s 693ms/step - loss: 0.1273 - accuracy: 0.9677 - precision: 0.9406 - recall: 0.8261
# Epoch 960/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1245 - accuracy: 0.9714 - precision: 0.9340 - recall: 0.8609
# Epoch 961/1000
# 12/12 [==============================] - 8s 687ms/step - loss: 0.1226 - accuracy: 0.9665 - precision: 0.9231 - recall: 0.8348
# Epoch 962/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1238 - accuracy: 0.9739 - precision: 0.9519 - recall: 0.8609
# Epoch 963/1000
# 12/12 [==============================] - 8s 687ms/step - loss: 0.1210 - accuracy: 0.9739 - precision: 0.9519 - recall: 0.8609
# Epoch 964/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1163 - accuracy: 0.9727 - precision: 0.9346 - recall: 0.8696
# Epoch 965/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1122 - accuracy: 0.9826 - precision: 0.9550 - recall: 0.9217
# Epoch 966/1000
# 12/12 [==============================] - 8s 693ms/step - loss: 0.1309 - accuracy: 0.9677 - precision: 0.9495 - recall: 0.8174
# Epoch 967/1000
# 12/12 [==============================] - 8s 686ms/step - loss: 0.1287 - accuracy: 0.9652 - precision: 0.9065 - recall: 0.8435
# Epoch 968/1000
# 12/12 [==============================] - 8s 694ms/step - loss: 0.1186 - accuracy: 0.9789 - precision: 0.9804 - recall: 0.8696
# Epoch 969/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1203 - accuracy: 0.9689 - precision: 0.9245 - recall: 0.8522
# Epoch 970/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1265 - accuracy: 0.9702 - precision: 0.9174 - recall: 0.8696
# Epoch 971/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1105 - accuracy: 0.9789 - precision: 0.9455 - recall: 0.9043
# Epoch 972/1000
# 12/12 [==============================] - 8s 687ms/step - loss: 0.1147 - accuracy: 0.9689 - precision: 0.9412 - recall: 0.8348
# Epoch 973/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1298 - accuracy: 0.9677 - precision: 0.9083 - recall: 0.8609
# Epoch 974/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1275 - accuracy: 0.9627 - precision: 0.8972 - recall: 0.8348
# Epoch 975/1000
# 12/12 [==============================] - 8s 690ms/step - loss: 0.1255 - accuracy: 0.9677 - precision: 0.9159 - recall: 0.8522
# Epoch 976/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1275 - accuracy: 0.9702 - precision: 0.9252 - recall: 0.8609
# Epoch 977/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1139 - accuracy: 0.9764 - precision: 0.9444 - recall: 0.8870
# Epoch 978/1000
# 12/12 [==============================] - 8s 693ms/step - loss: 0.1260 - accuracy: 0.9652 - precision: 0.9065 - recall: 0.8435
# Epoch 979/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1139 - accuracy: 0.9752 - precision: 0.9439 - recall: 0.8783
# Epoch 980/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1188 - accuracy: 0.9689 - precision: 0.9091 - recall: 0.8696
# Epoch 981/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1199 - accuracy: 0.9714 - precision: 0.9340 - recall: 0.8609
# Epoch 982/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1176 - accuracy: 0.9702 - precision: 0.9333 - recall: 0.8522
# Epoch 983/1000
# 12/12 [==============================] - 8s 690ms/step - loss: 0.1210 - accuracy: 0.9739 - precision: 0.9608 - recall: 0.8522
# Epoch 984/1000
# 12/12 [==============================] - 8s 682ms/step - loss: 0.1209 - accuracy: 0.9665 - precision: 0.9151 - recall: 0.8435
# Epoch 985/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1111 - accuracy: 0.9789 - precision: 0.9537 - recall: 0.8957
# Epoch 986/1000
# 12/12 [==============================] - 8s 683ms/step - loss: 0.1083 - accuracy: 0.9789 - precision: 0.9712 - recall: 0.8783
# Epoch 987/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1335 - accuracy: 0.9640 - precision: 0.9135 - recall: 0.8261
# Epoch 988/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1212 - accuracy: 0.9702 - precision: 0.9252 - recall: 0.8609
# Epoch 989/1000
# 12/12 [==============================] - 8s 690ms/step - loss: 0.1146 - accuracy: 0.9702 - precision: 0.9252 - recall: 0.8609
# Epoch 990/1000
# 12/12 [==============================] - 8s 690ms/step - loss: 0.1176 - accuracy: 0.9727 - precision: 0.9346 - recall: 0.8696
# Epoch 991/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1239 - accuracy: 0.9739 - precision: 0.9434 - recall: 0.8696
# Epoch 992/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1280 - accuracy: 0.9739 - precision: 0.9434 - recall: 0.8696
# Epoch 993/1000
# 12/12 [==============================] - 8s 688ms/step - loss: 0.1247 - accuracy: 0.9739 - precision: 0.9608 - recall: 0.8522
# Epoch 994/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1146 - accuracy: 0.9752 - precision: 0.9358 - recall: 0.8870
# Epoch 995/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1192 - accuracy: 0.9801 - precision: 0.9626 - recall: 0.8957
# Epoch 996/1000
# 12/12 [==============================] - 8s 700ms/step - loss: 0.1212 - accuracy: 0.9652 - precision: 0.9143 - recall: 0.8348
# Epoch 997/1000
# 12/12 [==============================] - 8s 691ms/step - loss: 0.1186 - accuracy: 0.9764 - precision: 0.9528 - recall: 0.8783
# Epoch 998/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1250 - accuracy: 0.9689 - precision: 0.9245 - recall: 0.8522
# Epoch 999/1000
# 12/12 [==============================] - 8s 692ms/step - loss: 0.1142 - accuracy: 0.9714 - precision: 0.9340 - recall: 0.8609
# Epoch 1000/1000
# 12/12 [==============================] - 8s 689ms/step - loss: 0.1258 - accuracy: 0.9665 - precision: 0.9074 - recall: 0.8522

# %% [markdown]
# ## O modelo é então salvo
#
# + Foi utilizado o modelo no formato hdf5

# %%
model.save('chatModel.h5')
# Out:
# 2023-05-02 18:38:41.934668: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 93763584 exceeds 10% of free system memory.
